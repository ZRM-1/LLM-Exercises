# %%
import matplotlib.pyplot as plt

# Example data
categories = ['COT', ' COT-Mod', 'Art-COT', 'Art-COT-Mod']
values = [82, 88, 94, 88]

# Plotting the bar chart
plt.bar(categories, values, color='navy')

# Adding labels and title
plt.xlabel('Prompt type')
plt.ylabel('Accuracy')
plt.title('Accuracy for different prompts')

# Display the plot
plt.show()
